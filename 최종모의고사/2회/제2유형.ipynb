# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import roc_auc_score, accuracy_score, classification_report, confusion_matrix
from sklearn.svm import SVR
from sklearn.preprocessing import LabelEncoder

pd.set_option('display.max.rows', 1000)

data = pd.read_csv('./data/Loan_payments_data.csv')

data['paid_off_time'] = pd.to_datetime(data['paid_off_time']) 
data['effective_date'] = pd.to_datetime(data['effective_date']) 
data['due_date'] = pd.to_datetime(data['due_date'])

fromdate_paid = min(data['paid_off_time'])
fromdate_effe = min(data['effective_date'])
fromdate_due = min(data['due_date'])

train, test = train_test_split(data, test_size=0.3, random_state=1000)

X_train = train.drop(['loan_status'], axis=1)
y_train = train[['Loan_ID','loan_status']]
X_test = test.drop(['loan_status'], axis=1)
y_test = test[['Loan_ID','loan_status']]

X_TEST = X_test.drop(['Loan_ID', 'past_due_days'], axis=1)

X = X_train.drop(['Loan_ID','past_due_days'], axis=1)
Y = y_train['loan_status'].map(lambda x: 1 if x == 'PAIDOFF' else 0)

X_TEST['paid_off_time'] = X_TEST['paid_off_time'].map(lambda x: 1 if x != None else x)
X['paid_off_time'] = X['paid_off_time'].map(lambda x: 1 if x != None else 0)

X_TEST['effective_date'] = (pd.to_datetime(X_TEST['effective_date']) - fromdate_effe).dt.days.astype(int)
X_TEST['due_date'] = (pd.to_datetime(X_TEST['due_date']) - fromdate_due).dt.days.astype(int)

X['effective_date'] = (pd.to_datetime(X['effective_date']) - fromdate_effe).dt.days.astype(int)
X['due_date'] = (pd.to_datetime(X['due_date']) - fromdate_due).dt.days.astype(int)

X_TEST['Gender'] = LabelEncoder().fit_transform(X_TEST['Gender'])
X_TEST['education'] = LabelEncoder().fit_transform(X_TEST['education'])

X['Gender'] = LabelEncoder().fit_transform(X['Gender'])
X['education'] = LabelEncoder().fit_transform(X['education'])

X_TRAIN ,X_VALID, Y_TRAIN, Y_VALID = train_test_split(X, Y, test_size=0.33, random_state=42)

rf = RandomForestClassifier(random_state=42, max_depth=42).fit(X_TRAIN, Y_TRAIN)
y_pred = rf.predict(X_VALID)
print('RF :', roc_auc_score(Y_VALID, y_pred))

gb = GradientBoostingClassifier(random_state=42, max_depth=100).fit(X_TRAIN, Y_TRAIN)
y_pred = gb.predict(X_VALID)
print('GB :', roc_auc_score(Y_VALID, y_pred))

svr = SVR(C=2).fit(X_TRAIN, Y_TRAIN)
y_pred = svr.predict(X_VALID)
print('SVM :', roc_auc_score(Y_VALID, y_pred))

test_pred = rf.predict(X_TEST)
result = pd.DataFrame({'Loan_ID':test['Loan_ID'], 'loan_status':test_pred})
result['loan_status'] = result['loan_status'].map(lambda x: 'PAIDOFF' if x == 1 else 'COLLECTION_PAIDOFF')
result.to_csv('000000.csv', index=False)
# Out:
# RF : 0.6028169014084508
# GB : 0.6057902973395931
# SVM : 0.6474178403755869

# %%
Y_TEST = y_test['loan_status'].map(lambda x: 1 if x == 'PAIDOFF' else 0)
print('RF :', roc_auc_score(Y_TEST, test_pred))
# print(classification_report(Y_TEST, test_pred))
# print(confusion_matrix(Y_TEST, test_pred))
# Out:
# RF : 0.6317750046563605

# %%
pd.concat([y_test, result], axis=1)
# Out:
#          Loan_ID         loan_status      Loan_ID         loan_status
# 319  xqd20160320          COLLECTION  xqd20160320  COLLECTION_PAIDOFF
# 207  xqd20160208             PAIDOFF  xqd20160208             PAIDOFF
# 22   xqd20160023             PAIDOFF  xqd20160023  COLLECTION_PAIDOFF
# 420  xqd20160421  COLLECTION_PAIDOFF  xqd20160421             PAIDOFF
# 352  xqd20160353          COLLECTION  xqd20160353             PAIDOFF
# 491  xqd20160492  COLLECTION_PAIDOFF  xqd20160492             PAIDOFF
# 60   xqd20160061             PAIDOFF  xqd20160061  COLLECTION_PAIDOFF
# 264  xqd20160265             PAIDOFF  xqd20160265             PAIDOFF
# 454  xqd20160455  COLLECTION_PAIDOFF  xqd20160455             PAIDOFF
# 21   xqd20160022             PAIDOFF  xqd20160022             PAIDOFF
# 427  xqd20160428  COLLECTION_PAIDOFF  xqd20160428  COLLECTION_PAIDOFF
# 43   xqd20160044             PAIDOFF  xqd20160044  COLLECTION_PAIDOFF
# 444  xqd20160445  COLLECTION_PAIDOFF  xqd20160445  COLLECTION_PAIDOFF
# 423  xqd20160424  COLLECTION_PAIDOFF  xqd20160424  COLLECTION_PAIDOFF
# 295  xqd20160296             PAIDOFF  xqd20160296             PAIDOFF
# 258  xqd20160259             PAIDOFF  xqd20160259             PAIDOFF
# 164  xqd20160165             PAIDOFF  xqd20160165             PAIDOFF
# 89   xqd90160090             PAIDOFF  xqd90160090             PAIDOFF
# 178  xqd20160179             PAIDOFF  xqd20160179  COLLECTION_PAIDOFF
# 25   xqd20160026             PAIDOFF  xqd20160026  COLLECTION_PAIDOFF
# 57   xqd20160058             PAIDOFF  xqd20160058  COLLECTION_PAIDOFF
# 347  xqd20160348          COLLECTION  xqd20160348             PAIDOFF
# 266  xqd20160267             PAIDOFF  xqd20160267             PAIDOFF
# 203  xqd20160204             PAIDOFF  xqd20160204             PAIDOFF
# 488  xqd20160489  COLLECTION_PAIDOFF  xqd20160489  COLLECTION_PAIDOFF
# 65   xqd20160066             PAIDOFF  xqd20160066             PAIDOFF
# 42   xqd20160043             PAIDOFF  xqd20160043             PAIDOFF
# 167  xqd20160168             PAIDOFF  xqd20160168             PAIDOFF
# 338  xqd20160339          COLLECTION  xqd20160339             PAIDOFF
# 61   xqd20160062             PAIDOFF  xqd20160062             PAIDOFF
# 189  xqd20160190             PAIDOFF  xqd20160190  COLLECTION_PAIDOFF
# 477  xqd20160478  COLLECTION_PAIDOFF  xqd20160478             PAIDOFF
# 180  xqd20160181             PAIDOFF  xqd20160181             PAIDOFF
# 328  xqd20160329          COLLECTION  xqd20160329             PAIDOFF
# 96   xqd20160097             PAIDOFF  xqd20160097             PAIDOFF
# 208  xqd20160209             PAIDOFF  xqd20160209             PAIDOFF
# 93   xqd20160094             PAIDOFF  xqd20160094  COLLECTION_PAIDOFF
# 26   xqd20160027             PAIDOFF  xqd20160027  COLLECTION_PAIDOFF
# 114  xqd20160115             PAIDOFF  xqd20160115             PAIDOFF
# 489  xqd20160490  COLLECTION_PAIDOFF  xqd20160490             PAIDOFF
# 367  xqd20160368          COLLECTION  xqd20160368  COLLECTION_PAIDOFF
# 116  xqd20160117             PAIDOFF  xqd20160117  COLLECTION_PAIDOFF
# 6    xqd20160007             PAIDOFF  xqd20160007  COLLECTION_PAIDOFF
# 229  xqd20160230             PAIDOFF  xqd20160230             PAIDOFF
# 4    xqd20160005             PAIDOFF  xqd20160005  COLLECTION_PAIDOFF
# 364  xqd20160365          COLLECTION  xqd20160365  COLLECTION_PAIDOFF
# 354  xqd20160355          COLLECTION  xqd20160355  COLLECTION_PAIDOFF
# 396  xqd20160397          COLLECTION  xqd20160397             PAIDOFF
# 263  xqd20160264             PAIDOFF  xqd20160264             PAIDOFF
# 222  xqd20160223             PAIDOFF  xqd20160223             PAIDOFF
# 388  xqd20160389          COLLECTION  xqd20160389  COLLECTION_PAIDOFF
# 346  xqd20160347          COLLECTION  xqd20160347  COLLECTION_PAIDOFF
# 98   xqd20160099             PAIDOFF  xqd20160099             PAIDOFF
# 37   xqd20160038             PAIDOFF  xqd20160038             PAIDOFF
# 363  xqd20160364          COLLECTION  xqd20160364             PAIDOFF
# 481  xqd20160482  COLLECTION_PAIDOFF  xqd20160482             PAIDOFF
# 235  xqd20160236             PAIDOFF  xqd20160236  COLLECTION_PAIDOFF
# 299  xqd20160300             PAIDOFF  xqd20160300             PAIDOFF
# 320  xqd20160321          COLLECTION  xqd20160321  COLLECTION_PAIDOFF
# 494  xqd20160495  COLLECTION_PAIDOFF  xqd20160495  COLLECTION_PAIDOFF
# 358  xqd20160359          COLLECTION  xqd20160359  COLLECTION_PAIDOFF
# 245  xqd20160246             PAIDOFF  xqd20160246             PAIDOFF
# 480  xqd20160481  COLLECTION_PAIDOFF  xqd20160481             PAIDOFF
# 426  xqd20160427  COLLECTION_PAIDOFF  xqd20160427  COLLECTION_PAIDOFF
# 52   xqd20160053             PAIDOFF  xqd20160053  COLLECTION_PAIDOFF
# 451  xqd20160452  COLLECTION_PAIDOFF  xqd20160452             PAIDOFF
# 280  xqd20160281             PAIDOFF  xqd20160281             PAIDOFF
# 24   xqd20160025             PAIDOFF  xqd20160025  COLLECTION_PAIDOFF
# 95   xqd20160096             PAIDOFF  xqd20160096             PAIDOFF
# 431  xqd20160432  COLLECTION_PAIDOFF  xqd20160432             PAIDOFF
# 450  xqd20160451  COLLECTION_PAIDOFF  xqd20160451             PAIDOFF
# 300  xqd20160301          COLLECTION  xqd20160301  COLLECTION_PAIDOFF
# 28   xqd20160029             PAIDOFF  xqd20160029             PAIDOFF
# 165  xqd20160166             PAIDOFF  xqd20160166  COLLECTION_PAIDOFF
# 118  xqd20160119             PAIDOFF  xqd20160119  COLLECTION_PAIDOFF
# 153  xqd20160154             PAIDOFF  xqd20160154             PAIDOFF
# 303  xqd20160304          COLLECTION  xqd20160304  COLLECTION_PAIDOFF
# 399  xqd20160400          COLLECTION  xqd20160400  COLLECTION_PAIDOFF
# 466  xqd20160467  COLLECTION_PAIDOFF  xqd20160467  COLLECTION_PAIDOFF
# 55   xqd20160056             PAIDOFF  xqd20160056             PAIDOFF
# 101  xqd20160102             PAIDOFF  xqd20160102             PAIDOFF
# 401  xqd20160402  COLLECTION_PAIDOFF  xqd20160402  COLLECTION_PAIDOFF
# 255  xqd20160256             PAIDOFF  xqd20160256             PAIDOFF
# 248  xqd20160249             PAIDOFF  xqd20160249             PAIDOFF
# 490  xqd20160491  COLLECTION_PAIDOFF  xqd20160491  COLLECTION_PAIDOFF
# 133  xqd20160134             PAIDOFF  xqd20160134  COLLECTION_PAIDOFF
# 395  xqd20160396          COLLECTION  xqd20160396  COLLECTION_PAIDOFF
# 479  xqd20160480  COLLECTION_PAIDOFF  xqd20160480  COLLECTION_PAIDOFF
# 236  xqd20160237             PAIDOFF  xqd20160237  COLLECTION_PAIDOFF
# 318  xqd20160319          COLLECTION  xqd20160319  COLLECTION_PAIDOFF
# 285  xqd20160286             PAIDOFF  xqd20160286             PAIDOFF
# 246  xqd20160247             PAIDOFF  xqd20160247             PAIDOFF
# 310  xqd20160311          COLLECTION  xqd20160311  COLLECTION_PAIDOFF
# 428  xqd20160429  COLLECTION_PAIDOFF  xqd20160429             PAIDOFF
# 46   xqd20160047             PAIDOFF  xqd20160047             PAIDOFF
# 459  xqd20160460  COLLECTION_PAIDOFF  xqd20160460             PAIDOFF
# 438  xqd20160439  COLLECTION_PAIDOFF  xqd20160439             PAIDOFF
# 272  xqd20160273             PAIDOFF  xqd20160273             PAIDOFF
# 136  xqd20160137             PAIDOFF  xqd20160137             PAIDOFF
# 32   xqd20160033             PAIDOFF  xqd20160033             PAIDOFF
# 177  xqd20160178             PAIDOFF  xqd20160178  COLLECTION_PAIDOFF
# 197  xqd20160198             PAIDOFF  xqd20160198  COLLECTION_PAIDOFF
# 418  xqd20160419  COLLECTION_PAIDOFF  xqd20160419             PAIDOFF
# 132  xqd20160133             PAIDOFF  xqd20160133  COLLECTION_PAIDOFF
# 33   xqd22169034             PAIDOFF  xqd22169034             PAIDOFF
# 313  xqd20160314          COLLECTION  xqd20160314  COLLECTION_PAIDOFF
# 150  xqd20160151             PAIDOFF  xqd20160151             PAIDOFF
# 142  xqd20160143             PAIDOFF  xqd20160143             PAIDOFF
# 380  xqd20160381          COLLECTION  xqd20160381  COLLECTION_PAIDOFF
# 120  xqd20160121             PAIDOFF  xqd20160121             PAIDOFF
# 453  xqd20160454  COLLECTION_PAIDOFF  xqd20160454  COLLECTION_PAIDOFF
# 448  xqd20160449  COLLECTION_PAIDOFF  xqd20160449  COLLECTION_PAIDOFF
# 66   xqd20160067             PAIDOFF  xqd20160067  COLLECTION_PAIDOFF
# 75   xqd20160076             PAIDOFF  xqd20160076             PAIDOFF
# 461  xqd20160462  COLLECTION_PAIDOFF  xqd20160462  COLLECTION_PAIDOFF
# 70   xqd20160071             PAIDOFF  xqd20160071             PAIDOFF
# 467  xqd20160468  COLLECTION_PAIDOFF  xqd20160468  COLLECTION_PAIDOFF
# 312  xqd20160313          COLLECTION  xqd20160313  COLLECTION_PAIDOFF
# 108  xqd20160109             PAIDOFF  xqd20160109             PAIDOFF
# 102  xqd20160103             PAIDOFF  xqd20160103             PAIDOFF
# 360  xqd20160361          COLLECTION  xqd20160361             PAIDOFF
# 92   xqd90163093             PAIDOFF  xqd90163093  COLLECTION_PAIDOFF
# 322  xqd20160323          COLLECTION  xqd20160323  COLLECTION_PAIDOFF
# 122  xqd20160123             PAIDOFF  xqd20160123             PAIDOFF
# 265  xqd20160266             PAIDOFF  xqd20160266             PAIDOFF
# 226  xqd20160227             PAIDOFF  xqd20160227             PAIDOFF
# 64   xqd20160065             PAIDOFF  xqd20160065  COLLECTION_PAIDOFF
# 117  xqd20160118             PAIDOFF  xqd20160118  COLLECTION_PAIDOFF
# 16   xqd20160017             PAIDOFF  xqd20160017  COLLECTION_PAIDOFF
# 391  xqd20125284          COLLECTION  xqd20125284  COLLECTION_PAIDOFF
# 252  xqd20160253             PAIDOFF  xqd20160253             PAIDOFF
# 297  xqd20160298             PAIDOFF  xqd20160298             PAIDOFF
# 329  xqd20160330          COLLECTION  xqd20160330             PAIDOFF
# 446  xqd20420447  COLLECTION_PAIDOFF  xqd20420447             PAIDOFF
# 34   xqd20160035             PAIDOFF  xqd20160035             PAIDOFF
# 179  xqd20160180             PAIDOFF  xqd20160180             PAIDOFF
# 15   xqd20160016             PAIDOFF  xqd20160016  COLLECTION_PAIDOFF
# 392  xqd20160393          COLLECTION  xqd20160393  COLLECTION_PAIDOFF
# 215  xqd20160216             PAIDOFF  xqd20160216             PAIDOFF
# 206  xqd20160207             PAIDOFF  xqd20160207  COLLECTION_PAIDOFF
# 268  xqd20160269             PAIDOFF  xqd20160269             PAIDOFF
# 63   xqd20160064             PAIDOFF  xqd20160064  COLLECTION_PAIDOFF
# 465  xqd20169466  COLLECTION_PAIDOFF  xqd20169466             PAIDOFF
# 183  xqd20160184             PAIDOFF  xqd20160184             PAIDOFF
# 82   xqd20160083             PAIDOFF  xqd20160083             PAIDOFF
# 237  xqd20160238             PAIDOFF  xqd20160238             PAIDOFF
# 181  xqd20160182             PAIDOFF  xqd20160182             PAIDOFF
# 405  xqd20160406  COLLECTION_PAIDOFF  xqd20160406  COLLECTION_PAIDOFF
# 296  xqd20160297             PAIDOFF  xqd20160297             PAIDOFF
# 281  xqd20160282             PAIDOFF  xqd20160282             PAIDOFF
